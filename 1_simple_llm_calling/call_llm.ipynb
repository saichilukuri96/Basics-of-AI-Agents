# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Call LLM using Google LLM API

# %%
llm  =  ChatGoogleGenerativeAI(model = "gemma-4-31b-it")
response = llm.invoke("How many moons does Jupiter have?")
print(response.text)
# Out:
# Jupiter has **95 recognized moons**.
#
# This number can change as astronomers discover new, smaller moons using more powerful telescopes. The most famous of these are the four largest, known as the **Galilean moons**: Io, Europa, Ganymede, and Callisto.

# %%
llm = ChatGoogleGenerativeAI(model = "gemma-4-31b-it")
reponse = llm.invoke([
    ["system" , "You are a helpful assistant that answers in short one line"],
    ["human","How many moons does Jupiter have?"]
])
print(reponse.text)
# Out:
# Jupiter has 95 known moons.

# %% [markdown]
# ## Temperature

# %%
prompt = " Write a single tagline for a quirky coffeeshop. Only output the tagline, nothing else"
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", temperature = 0)
response = llm.invoke(prompt)
print(response.text)
# Out:
# Where the coffee winks back.

# %%
prompt = " Write a single tagline for a quirky coffeeshop. Only output the tagline, nothing else"
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", temperature = 1)
response = llm.invoke(prompt)
print(response.text)
# Out:
# Percolating Peculiarity.

# %% [markdown]
# ## Call LLM Using Groq Models

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model = "qwen/qwen3-32b",reasoning_format = "parsed")

messages = [
    (
        "system",
        "You are a helpful assistant that gives a short answer to a question",
    ),
    (
        "human",
        "How many moons does Jupiter have ?",
    ),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Jupiter has **79 confirmed moons** as of the latest data (as of 2023). The four largest are the Galilean moons: Io, Europa, Ganymede, and Callisto.
